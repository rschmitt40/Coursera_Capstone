# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
import seaborn as sb

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# ...

# %%
ax = df[df["SEVERITYCODE"] == 1].plot(kind = "scatter", x = "X", y = "Y", color = "Blue", label = "Property Damage")
plt.show()

# %%
ax = df[df["SEVERITYCODE"] == 2].plot(kind = "scatter", x = "X", y = "Y", color = "Red", label = "Injury Collision")
plt.show()

# %%
sev1 = df[df["SEVERITYCODE"] == 1]
xsev1 = sev1["X"]
ysev1 = sev1["Y"]

sev2 = df[df["SEVERITYCODE"] == 2]
xsev2 = sev2["X"]
ysev2 = sev2["Y"]

# %%
heatmap, xedges, yedges = np.histogram2d(ysev1, xsev1, bins=(150,150))
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

# Plot heatmap
plt.clf()
plt.title('Seattle Property Damage Heatmap')
plt.ylabel('y')
plt.xlabel('x')
plt.imshow(heatmap, extent=extent, origin= 'lower')
plt.show()

# %%
heatmap, xedges, yedges = np.histogram2d(ysev2, xsev2, bins=(150,150))
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

# Plot heatmap
plt.clf()
plt.title('Seattle Injury Collision Heatmap')
plt.ylabel('y')
plt.xlabel('x')
plt.imshow(heatmap, extent=extent, origin= 'lower')
plt.show()
